# %%
from keras.models import Sequential, Model
from kerasfrom keras.models import Sequential, Model
from tqdm import tqdm
import numpy as np
import pandas as pd
# Out:
#   File "<ipython-input-9-338b9ddb3914>", line 2
#     from kerasfrom keras.models import Sequential, Model
#                        ^
# SyntaxError: invalid syntax

# %%
model=Sequential()
model.add(Conv1D(filters=64,kernel_size=3,strides=1,activation='sigmoid',padding="same",input_shape=(2600,1)))
model.add(BatchNormalization())
model.add(Conv1D(filters=64,kernel_size=3,strides=1,activation='sigmoid',padding="same"))
model.add(MaxPool1D(pool_size=4))
model.add(Dropout(0.25))
model.add(Conv1D(filters=32,kernel_size=3,strides=1,activation='sigmoid',padding="same"))
model.add(BatchNormalization())
model.add(Conv1D(filters=32,kernel_size=3,strides=1,activation='relu',padding="same"))
model.add(BatchNormalization())
model.add(MaxPool1D(pool_size=4))
model.add(Conv1D(filters=32,kernel_size=3,strides=1,activation='relu',padding="same"))
model.add(BatchNormalization())
model.add(MaxPool1D(pool_size=2,strides=2))
model.add(Conv1D(filters=32,kernel_size=3,strides=1,activation='relu',padding="same"))
model.add(BatchNormalization())
model.add(Conv1D(filters=32,kernel_size=3,strides=1,activation='relu',padding="same"))
model.add(BatchNormalization())
model.add(MaxPool1D(pool_size=2,strides=2))
model.add(Conv1D(filters=32,kernel_size=3,strides=1,activation='relu',padding="same"))
model.add(Dropout(0.25))
model.add(BatchNormalization())
model.add(Conv1D(filters=32,kernel_size=3,strides=1,activation='relu',padding="same"))
model.add(Dropout(0.25))
model.add(BatchNormalization())
model.add(Conv1D(filters=32,kernel_size=3,strides=1,activation='relu',padding="same"))
model.add(Dropout(0.25))
model.add(BatchNormalization())
model.add(MaxPool1D(pool_size=2,strides=1))
model.add(Flatten())
model.add(Dense(128, activation='sigmoid'))  
model.add(Dense(32, activation='sigmoid'))   
model.add(Dropout(0.25))
# 输出层
model.add(Dense(3, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 2600, 64)          256
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2600, 64)          256
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 2600, 64)          12352
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 650, 64)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 650, 64)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 650, 32)           6176
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 650, 32)           128
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 650, 32)           3104
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 650, 32)           128
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 162, 32)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 162, 32)           3104
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 162, 32)           128
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 81, 32)            0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 81, 32)            3104
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 81, 32)            128
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 81, 32)            3104
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 81, 32)            128
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 40, 32)            0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 40, 32)            3104
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 40, 32)            0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 40, 32)            128
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 40, 32)            3104
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 40, 32)            0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 40, 32)            128
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 40, 32)            3104
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 40, 32)            0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 40, 32)            128
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 39, 32)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1248)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               159872
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 205,891
# Trainable params: 205,251
# Non-trainable params: 640
# _________________________________________________________________

# %%
model_layer_xgb = Model(inputs=model.input,outputs=model.get_layer('dense_2').output)

# %%
from keras.models import Sequential, Model

# %%
model_layer_xgb.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1_input (InputLayer)  (None, 2600, 1)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2600, 64)          256
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2600, 64)          256
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 2600, 64)          12352
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 650, 64)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 650, 64)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 650, 32)           6176
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 650, 32)           128
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 650, 32)           3104
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 650, 32)           128
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 162, 32)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 162, 32)           3104
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 162, 32)           128
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 81, 32)            0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 81, 32)            3104
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 81, 32)            128
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 81, 32)            3104
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 81, 32)            128
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 40, 32)            0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 40, 32)            3104
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 40, 32)            0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 40, 32)            128
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 40, 32)            3104
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 40, 32)            0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 40, 32)            128
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 40, 32)            3104
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 40, 32)            0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 40, 32)            128
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 39, 32)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1248)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               159872
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                4128
# =================================================================
# Total params: 205,792
# Trainable params: 205,152
# Non-trainable params: 640
# _________________________________________________________________
